# %%
import pandas as pd
import numpy as np
from pandas import Series

object = Series([5,6,4,7])

print(object)

print (object.values)
print (object.index)


#converting numpy arrays to series

data_array = np.array ([20,40,60])

print (data_array)

s= Series(data_array)

print (s)

#using custom indexes
s = Series(data_array, index = ['index1','index2','index3'])

print (s)
# Out:
# 0    5
# 1    6
# 2    4
# 3    7
# dtype: int64
# [5 6 4 7]
# RangeIndex(start=0, stop=4, step=1)
# [20 40 60]
# 0    20
# 1    40
# 2    60
# dtype: int64
# index1    20
# index2    40
# index3    60
# dtype: int64

# %%
#using real life indexes


data2 = Series (data_array , index = ['ola', 'uber', 'taxify'])

print (data2)

print (data2['uber'])

print (data2[data2 >=40])
# Out:
# ola       20
# uber      40
# taxify    60
# dtype: int64
# 40
# uber      40
# taxify    60
# dtype: int64

# %%
#using boolean conditions

print ('taxify' in data2)
# Out:
# True

# %%
import pandas as pd
from pandas import DataFrame
revenue_df=pd.read_clipboard()
print (revenue_df)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-42-b9c5d977e917> in <module>()
#       1 import pandas as pd
#       2 from pandas import DataFrame
# ----> 3 revenue_df=pd.read_clipboard()
#       4 print (revenue_df)
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      61         sep = '\s+'
#      62
# ---> 63     return read_table(StringIO(text), sep=sep, **kwargs)
#      64
#      65
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.linspace(0, 10, 100)
b = np.exp(-a)
plt.plot(a, b)
plt.show()

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy.random import rand
a = rand(100)
b = rand(100)
plt.scatter(a, b)
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy.random import normal,rand
x = normal(size=200)
plt.hist(x, bins=30)
plt.show()
